# %% [markdown]
# <a href="https://colab.research.google.com/github/honeybunch00/idk/blob/main/Copy_of_hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Witaj w Google Colab!

# %%
pierwsza_zmienna = 1
druga_zmienna = 2.43
trzecia_zmienna = "hello"

# %%
# to jest komentarz

'''
to jest blok
komentarzy
mogę dodawać ich wiele w 
różnych linijkach
'''
# Out:
# '\nto jest blok\nkomentarzy\nmogę dodawać ich wiele w \nróżnych linijkach\n'

# %%
print('Marta Wleklińśka')
print(pierwsza_zmienna)
print(druga_zmienna, trzecia_zmienna)
print('wypisałem',"wszystkie zmienne")
# Out:
# Marta Wleklińśka
# 1
# 2.43 hello
# wypisałem wszystkie zmienne

# %%
wynik_dodawania = pierwsza_zmienna + druga_zmienna # dozwolone są oczywiście także inne operacje matematyczne
print(wynik_dodawania)
# Out:
# 3.43

# %%
# wyrażenia warunkowe

zmienna_testowa = 8
if zmienna_testowa == 8: # == oznacza porównanie, = to przypisanie!
  print('Twoja zmienna to ósemka!')
elif zmienna_testowa < 8:
  print('Twoja zmienna jest mniejsza niż 8.')
else:
  print('Twoja zmienna jest większa niż 8.')

### zmień kod tak, żeby zostały wypisane wszystkie 3 napisy
# Out:
# Twoja zmienna to ósemka!

# %%
# pętla while

i = 2
while i < 10:
  print('cześć!')
  print(i)
  i = i + 5 # przy każdym przejściu pętli zwiększam i
# Out:
# cześć!
# 2
# cześć!
# 7

# %%
# umieść tutaj kod, który wypisze 8 razy Twoje imię i nazwisko (while)

# %%
# pętla for

for i in range(0,10):
  print(i)
  print('hej!')
# Out:
# 0
# hej!
# 1
# hej!
# 2
# hej!
# 3
# hej!
# 4
# hej!
# 5
# hej!
# 6
# hej!
# 7
# hej!
# 8
# hej!
# 9
# hej!

# %%
# umieść tutaj kod, który wypisze 8 razy Twoje imię i nazwisko (for)

# %%
# funkcja z jednym argumentem

def moja_funkcja(a):
  b = a*a
  print(b)

# %%
moja_funkcja(10)
moja_funkcja(8)
# Out:
# 100
# 64

# %%
# funkcja z kilkoma argumentami

def moja_funkcja_2(a, b, c):
  d = a*a + b - c
  return d # zwracanie

# %%
moja_funkcja_2(1,2,3)
# Out:
# 0

# %%
# osoba

class Osoba: 
    def __init__(self, imie, nazwisko, wiek):
        self.imie = imie
        self.nazwisko = nazwisko
        self.wiek = wiek
    def przedstaw_sie(self):
        print(f"Jestem {self.imie} {self.nazwisko}. Mam {self.wiek} lat.")
    def urodziny(self):
        wiek_przed = self.wiek
        self.wiek += 1
        return wiek_przed

# %%
# tworzymy dwa obiekty klasy Osoba
Jan = Osoba("Jan", "Nowak", 48)
Adam = Osoba("Adam", "Mickiewicz", 220)

# wywołujemy metodę przedstaw_sie() na każdym z nich
Jan.przedstaw_sie()
Adam.przedstaw_sie()

wiek_Adama_przed = Adam.urodziny()
Adam.przedstaw_sie()
print(f"Wiek Adama sprzed urodzin: {wiek_Adama_przed}")

# odwołujemy się do pól, modyfikujemy je
Jan.imie = "Stanisław"
Jan.nazwisko = "Witkiewicz"
Jan.wiek = 133

Jan.przedstaw_sie()
print(Jan.imie)
# Out:
# Jestem Jan Nowak. Mam 48 lat.
# Jestem Adam Mickiewicz. Mam 220 lat.
# Jestem Adam Mickiewicz. Mam 221 lat.
# Wiek Adama sprzed urodzin: 220
# Jestem Stanisław Witkiewicz. Mam 133 lat.
# Stanisław

# %%
# moduły 1

import math
math.sqrt(9)
# Out:
# 3.0

# %%
# moduły 2

from math import sqrt
sqrt(9)
# Out:
# 3.0

# %% [markdown]
# ### Dane i analiza

# %%
# ładowanie plików z dysku komputera

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-862a2e5e-85f1-4704-a16e-ce421f6bd28a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-862a2e5e-85f1-4704-a16e-ce421f6bd28a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prbne.csv to prbne.csv
# User uploaded file "prbne.csv" with length 20222 bytes

# %%
import pandas as pd # teraz do funkcji z tego modułu możemy się odwoływać poprzez pd
import numpy as np # teraz do funkcji z tego modułu możemy się odwoływać poprzez np

# %%
pd.read_csv('prbne.csv')
# Out:
#            id       date  confirmed  deaths  recovered  tests  vaccines  \
# 0    8dea749d  27/4/2021        NaN     NaN        NaN    NaN    2400.0
# 1    8dea749d  28/4/2021        NaN     NaN        NaN    NaN       NaN
# 2    8dea749d  29/4/2021        NaN     NaN        NaN    NaN       NaN
# 3    8dea749d  30/4/2021        NaN     NaN        NaN    NaN       NaN
# 4    8dea749d   1/5/2021        NaN     NaN        NaN    NaN       NaN
# ..        ...        ...        ...     ...        ...    ...       ...
# 201  d7f0f2d6   3/5/2020      148.0     0.0        0.0  623.0       NaN
# 202  d7f0f2d6   4/5/2020      149.0     0.0        0.0  623.0       NaN
# 203  d7f0f2d6   5/5/2020      149.0     0.0        0.0  623.0       NaN
# 204  d7f0f2d6   6/5/2020      149.0     0.0        0.0  623.0       NaN
# 205  d7f0f2d6   7/5/2020      149.0     0.0        0.0  623.0       NaN
#
#      people_vaccinated  people_fully_vaccinated   hosp  ...  iso_alpha_3  \
# 0               2400.0                      NaN    NaN  ...          TUV
# 1                  NaN                      NaN    NaN  ...          TUV
# 2                  NaN                      NaN    NaN  ...          TUV
# 3                  NaN                      NaN    NaN  ...          TUV
# 4                  NaN                      NaN    NaN  ...          TUV
# ..                 ...                      ...    ...  ...          ...
# 201                NaN                      NaN  148.0  ...          NaN
# 202                NaN                      NaN  148.0  ...          NaN
# 203                NaN                      NaN  149.0  ...          NaN
# 204                NaN                      NaN  149.0  ...          NaN
# 205                NaN                      NaN  149.0  ...          NaN
#
#      iso_alpha_2  iso_numeric  iso_currency  key_local  key_google_mobility  \
# 0             TV        798.0           AUD        NaN                  NaN
# 1             TV        798.0           AUD        NaN                  NaN
# 2             TV        798.0           AUD        NaN                  NaN
# 3             TV        798.0           AUD        NaN                  NaN
# 4             TV        798.0           AUD        NaN                  NaN
# ..           ...          ...           ...        ...                  ...
# 201          NaN          NaN           NaN        NaN                  NaN
# 202          NaN          NaN           NaN        NaN                  NaN
# 203          NaN          NaN           NaN        NaN                  NaN
# 204          NaN          NaN           NaN        NaN                  NaN
# 205          NaN          NaN           NaN        NaN                  NaN
#
#      key_apple_mobility  key_jhu_csse  key_nuts  key_gadm
# 0                   NaN           NaN       NaN       TUV
# 1                   NaN           NaN       NaN       TUV
# 2                   NaN           NaN       NaN       TUV
# 3                   NaN           NaN       NaN       TUV
# 4                   NaN           NaN       NaN       TUV
# ..                  ...           ...       ...       ...
# 201                 NaN           NaN       NaN       NaN
# 202                 NaN           NaN       NaN       NaN
# 203                 NaN           NaN       NaN       NaN
# 204                 NaN           NaN       NaN       NaN
# 205                 NaN           NaN       NaN       NaN
#
# [206 rows x 47 columns]

# %%
df = pd.read_csv('prbne.csv') # zapisujemy naszą RAMKĘ DANYCH pod zmienną df

# %%
df.head(10) # wypisuje nam 10 pierwszych wierszy
# Out:
#          id       date  confirmed  deaths  recovered  tests  vaccines  \
# 0  8dea749d  27/4/2021        NaN     NaN        NaN    NaN    2400.0
# 1  8dea749d  28/4/2021        NaN     NaN        NaN    NaN       NaN
# 2  8dea749d  29/4/2021        NaN     NaN        NaN    NaN       NaN
# 3  8dea749d  30/4/2021        NaN     NaN        NaN    NaN       NaN
# 4  8dea749d   1/5/2021        NaN     NaN        NaN    NaN       NaN
# 5  8dea749d   2/5/2021        NaN     NaN        NaN    NaN       NaN
# 6  8dea749d   3/5/2021        NaN     NaN        NaN    NaN       NaN
# 7  8dea749d   4/5/2021        NaN     NaN        NaN    NaN       NaN
# 8  8dea749d   5/5/2021        NaN     NaN        NaN    NaN       NaN
# 9  8dea749d   6/5/2021        NaN     NaN        NaN    NaN       NaN
#
#    people_vaccinated  people_fully_vaccinated  hosp  ...  iso_alpha_3  \
# 0             2400.0                      NaN   NaN  ...          TUV
# 1                NaN                      NaN   NaN  ...          TUV
# 2                NaN                      NaN   NaN  ...          TUV
# 3                NaN                      NaN   NaN  ...          TUV
# 4                NaN                      NaN   NaN  ...          TUV
# 5                NaN                      NaN   NaN  ...          TUV
# 6                NaN                      NaN   NaN  ...          TUV
# 7                NaN                      NaN   NaN  ...          TUV
# 8                NaN                      NaN   NaN  ...          TUV
# 9                NaN                      NaN   NaN  ...          TUV
#
#    iso_alpha_2  iso_numeric  iso_currency  key_local  key_google_mobility  \
# 0           TV        798.0           AUD        NaN                  NaN
# 1           TV        798.0           AUD        NaN                  NaN
# 2           TV        798.0           AUD        NaN                  NaN
# 3           TV        798.0           AUD        NaN                  NaN
# 4           TV        798.0           AUD        NaN                  NaN
# 5           TV        798.0           AUD        NaN                  NaN
# 6           TV        798.0           AUD        NaN                  NaN
# 7           TV        798.0           AUD        NaN                  NaN
# 8           TV        798.0           AUD        NaN                  NaN
# 9           TV        798.0           AUD        NaN                  NaN
#
#    key_apple_mobility  key_jhu_csse  key_nuts  key_gadm
# 0                 NaN           NaN       NaN       TUV
# 1                 NaN           NaN       NaN       TUV
# 2                 NaN           NaN       NaN       TUV
# 3                 NaN           NaN       NaN       TUV
# 4                 NaN           NaN       NaN       TUV
# 5                 NaN           NaN       NaN       TUV
# 6                 NaN           NaN       NaN       TUV
# 7                 NaN           NaN       NaN       TUV
# 8                 NaN           NaN       NaN       TUV
# 9                 NaN           NaN       NaN       TUV
#
# [10 rows x 47 columns]

# %% [markdown]
# ### Uruchom poniższe komórki - co się stało?

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# confirmed                                 80.333333
# deaths                                     0.000000
# recovered                                  0.000000
# tests                                    500.187500
# vaccines                                7361.142857
# people_vaccinated                       4880.857143
# people_fully_vaccinated                 4340.500000
# hosp                                     122.062500
# icu                                             NaN
# vent                                            NaN
# school_closing                                  NaN
# workplace_closing                               NaN
# cancel_events                                   NaN
# gatherings_restrictions                         NaN
# transport_closing                               NaN
# stay_home_restrictions                          NaN
# internal_movement_restrictions                  NaN
# international_movement_restrictions             NaN
# information_campaigns                           NaN
# testing_policy                                  NaN
# contact_tracing                                 NaN
# facial_coverings                                NaN
# vaccination_policy                              NaN
# elderly_people_protection                       NaN
# government_response_index                       NaN
# stringency_index                                NaN
# containment_health_index                        NaN
# economic_support_index                          NaN
# administrative_area_level                  1.000000
# administrative_area_level_2                     NaN
# administrative_area_level_3                     NaN
# latitude                                  -8.000000
# longitude                                178.000000
# population                             10222.587379
# iso_numeric                              798.000000
# key_local                                       NaN
# key_google_mobility                             NaN
# key_apple_mobility                              NaN
# key_jhu_csse                                    NaN
# key_nuts                                        NaN
# dtype: float64

# %%
df.describe()
# Out:
#         confirmed  deaths  recovered       tests      vaccines  \
# count   27.000000    17.0       16.0   16.000000      7.000000
# mean    80.333333     0.0        0.0  500.187500   7361.142857
# std     69.073539     0.0        0.0  229.003412   4137.707031
# min      1.000000     0.0        0.0    4.000000   2400.000000
# 25%      9.000000     0.0        0.0  551.000000   3586.000000
# 50%     91.000000     0.0        0.0  623.000000   8289.000000
# 75%    148.000000     0.0        0.0  623.000000  10776.500000
# max    149.000000     0.0        0.0  623.000000  12114.000000
#
#        people_vaccinated  people_fully_vaccinated        hosp  icu  vent  ...  \
# count           7.000000                 4.000000   16.000000  0.0   0.0  ...
# mean         4880.857143              4340.500000  122.062500  NaN   NaN  ...
# std          1769.427066              1491.422699   49.727885  NaN   NaN  ...
# min          2400.000000              2301.000000    1.000000  NaN   NaN  ...
# 25%          3586.000000              3969.000000  133.750000  NaN   NaN  ...
# 50%          5988.000000              4588.500000  148.000000  NaN   NaN  ...
# 75%          6188.000000              4960.000000  148.000000  NaN   NaN  ...
# max          6230.000000              5884.000000  149.000000  NaN   NaN  ...
#
#        administrative_area_level_3  latitude  longitude    population  \
# count                          0.0     179.0      179.0    206.000000
# mean                           NaN      -8.0      178.0  10222.587379
# std                            NaN       0.0        0.0   3356.718955
# min                            NaN      -8.0      178.0    623.000000
# 25%                            NaN      -8.0      178.0  11508.000000
# 50%                            NaN      -8.0      178.0  11508.000000
# 75%                            NaN      -8.0      178.0  11508.000000
# max                            NaN      -8.0      178.0  11508.000000
#
#        iso_numeric  key_local  key_google_mobility  key_apple_mobility  \
# count        179.0        0.0                  0.0                 0.0
# mean         798.0        NaN                  NaN                 NaN
# std            0.0        NaN                  NaN                 NaN
# min          798.0        NaN                  NaN                 NaN
# 25%          798.0        NaN                  NaN                 NaN
# 50%          798.0        NaN                  NaN                 NaN
# 75%          798.0        NaN                  NaN                 NaN
# max          798.0        NaN                  NaN                 NaN
#
#        key_jhu_csse  key_nuts
# count           0.0       0.0
# mean            NaN       NaN
# std             NaN       NaN
# min             NaN       NaN
# 25%             NaN       NaN
# 50%             NaN       NaN
# 75%             NaN       NaN
# max             NaN       NaN
#
# [8 rows x 40 columns]

# %%
df.shape
# Out:
# (206, 47)

# %%
df.drop(['tests','recovered'],axis=1).plot(figsize=(20,10))

# %%
df.corr()
# Out:
#                                      confirmed  deaths  recovered     tests  \
# confirmed                             1.000000     NaN        NaN  0.914062
# deaths                                     NaN     NaN        NaN       NaN
# recovered                                  NaN     NaN        NaN       NaN
# tests                                 0.914062     NaN        NaN  1.000000
# vaccines                                   NaN     NaN        NaN       NaN
# people_vaccinated                          NaN     NaN        NaN       NaN
# people_fully_vaccinated                    NaN     NaN        NaN       NaN
# hosp                                  0.939244     NaN        NaN  0.995855
# icu                                        NaN     NaN        NaN       NaN
# vent                                       NaN     NaN        NaN       NaN
# school_closing                             NaN     NaN        NaN       NaN
# workplace_closing                          NaN     NaN        NaN       NaN
# cancel_events                              NaN     NaN        NaN       NaN
# gatherings_restrictions                    NaN     NaN        NaN       NaN
# transport_closing                          NaN     NaN        NaN       NaN
# stay_home_restrictions                     NaN     NaN        NaN       NaN
# internal_movement_restrictions             NaN     NaN        NaN       NaN
# international_movement_restrictions        NaN     NaN        NaN       NaN
# information_campaigns                      NaN     NaN        NaN       NaN
# testing_policy                             NaN     NaN        NaN       NaN
# contact_tracing                            NaN     NaN        NaN       NaN
# facial_coverings                           NaN     NaN        NaN       NaN
# vaccination_policy                         NaN     NaN        NaN       NaN
# elderly_people_protection                  NaN     NaN        NaN       NaN
# government_response_index                  NaN     NaN        NaN       NaN
# stringency_index                           NaN     NaN        NaN       NaN
# containment_health_index                   NaN     NaN        NaN       NaN
# economic_support_index                     NaN     NaN        NaN       NaN
# administrative_area_level                  NaN     NaN        NaN       NaN
# administrative_area_level_2                NaN     NaN        NaN       NaN
# administrative_area_level_3                NaN     NaN        NaN       NaN
# latitude                                   NaN     NaN        NaN       NaN
# longitude                                  NaN     NaN        NaN       NaN
# population                           -0.833170     NaN        NaN       NaN
# iso_numeric                                NaN     NaN        NaN       NaN
# key_local                                  NaN     NaN        NaN       NaN
# key_google_mobility                        NaN     NaN        NaN       NaN
# key_apple_mobility                         NaN     NaN        NaN       NaN
# key_jhu_csse                               NaN     NaN        NaN       NaN
# key_nuts                                   NaN     NaN        NaN       NaN
#
#                                      vaccines  people_vaccinated  \
# confirmed                                 NaN                NaN
# deaths                                    NaN                NaN
# recovered                                 NaN                NaN
# tests                                     NaN                NaN
# vaccines                             1.000000           0.939474
# people_vaccinated                    0.939474           1.000000
# people_fully_vaccinated              0.999834           0.964521
# hosp                                      NaN                NaN
# icu                                       NaN                NaN
# vent                                      NaN                NaN
# school_closing                            NaN                NaN
# workplace_closing                         NaN                NaN
# cancel_events                             NaN                NaN
# gatherings_restrictions                   NaN                NaN
# transport_closing                         NaN                NaN
# stay_home_restrictions                    NaN                NaN
# internal_movement_restrictions            NaN                NaN
# international_movement_restrictions       NaN                NaN
# information_campaigns                     NaN                NaN
# testing_policy                            NaN                NaN
# contact_tracing                           NaN                NaN
# facial_coverings                          NaN                NaN
# vaccination_policy                        NaN                NaN
# elderly_people_protection                 NaN                NaN
# government_response_index                 NaN                NaN
# stringency_index                          NaN                NaN
# containment_health_index                  NaN                NaN
# economic_support_index                    NaN                NaN
# administrative_area_level                 NaN                NaN
# administrative_area_level_2               NaN                NaN
# administrative_area_level_3               NaN                NaN
# latitude                                  NaN                NaN
# longitude                                 NaN                NaN
# population                                NaN                NaN
# iso_numeric                               NaN                NaN
# key_local                                 NaN                NaN
# key_google_mobility                       NaN                NaN
# key_apple_mobility                        NaN                NaN
# key_jhu_csse                              NaN                NaN
# key_nuts                                  NaN                NaN
#
#                                      people_fully_vaccinated      hosp  icu  \
# confirmed                                                NaN  0.939244  NaN
# deaths                                                   NaN       NaN  NaN
# recovered                                                NaN       NaN  NaN
# tests                                                    NaN  0.995855  NaN
# vaccines                                            0.999834       NaN  NaN
# people_vaccinated                                   0.964521       NaN  NaN
# people_fully_vaccinated                             1.000000       NaN  NaN
# hosp                                                     NaN  1.000000  NaN
# icu                                                      NaN       NaN  NaN
# vent                                                     NaN       NaN  NaN
# school_closing                                           NaN       NaN  NaN
# workplace_closing                                        NaN       NaN  NaN
# cancel_events                                            NaN       NaN  NaN
# gatherings_restrictions                                  NaN       NaN  NaN
# transport_closing                                        NaN       NaN  NaN
# stay_home_restrictions                                   NaN       NaN  NaN
# internal_movement_restrictions                           NaN       NaN  NaN
# international_movement_restrictions                      NaN       NaN  NaN
# information_campaigns                                    NaN       NaN  NaN
# testing_policy                                           NaN       NaN  NaN
# contact_tracing                                          NaN       NaN  NaN
# facial_coverings                                         NaN       NaN  NaN
# vaccination_policy                                       NaN       NaN  NaN
# elderly_people_protection                                NaN       NaN  NaN
# government_response_index                                NaN       NaN  NaN
# stringency_index                                         NaN       NaN  NaN
# containment_health_index                                 NaN       NaN  NaN
# economic_support_index                                   NaN       NaN  NaN
# administrative_area_level                                NaN       NaN  NaN
# administrative_area_level_2                              NaN       NaN  NaN
# administrative_area_level_3                              NaN       NaN  NaN
# latitude                                                 NaN       NaN  NaN
# longitude                                                NaN       NaN  NaN
# population                                               NaN       NaN  NaN
# iso_numeric                                              NaN       NaN  NaN
# key_local                                                NaN       NaN  NaN
# key_google_mobility                                      NaN       NaN  NaN
# key_apple_mobility                                       NaN       NaN  NaN
# key_jhu_csse                                             NaN       NaN  NaN
# key_nuts                                                 NaN       NaN  NaN
#
#                                      vent  ...  administrative_area_level_3  \
# confirmed                             NaN  ...                          NaN
# deaths                                NaN  ...                          NaN
# recovered                             NaN  ...                          NaN
# tests                                 NaN  ...                          NaN
# vaccines                              NaN  ...                          NaN
# people_vaccinated                     NaN  ...                          NaN
# people_fully_vaccinated               NaN  ...                          NaN
# hosp                                  NaN  ...                          NaN
# icu                                   NaN  ...                          NaN
# vent                                  NaN  ...                          NaN
# school_closing                        NaN  ...                          NaN
# workplace_closing                     NaN  ...                          NaN
# cancel_events                         NaN  ...                          NaN
# gatherings_restrictions               NaN  ...                          NaN
# transport_closing                     NaN  ...                          NaN
# stay_home_restrictions                NaN  ...                          NaN
# internal_movement_restrictions        NaN  ...                          NaN
# international_movement_restrictions   NaN  ...                          NaN
# information_campaigns                 NaN  ...                          NaN
# testing_policy                        NaN  ...                          NaN
# contact_tracing                       NaN  ...                          NaN
# facial_coverings                      NaN  ...                          NaN
# vaccination_policy                    NaN  ...                          NaN
# elderly_people_protection             NaN  ...                          NaN
# government_response_index             NaN  ...                          NaN
# stringency_index                      NaN  ...                          NaN
# containment_health_index              NaN  ...                          NaN
# economic_support_index                NaN  ...                          NaN
# administrative_area_level             NaN  ...                          NaN
# administrative_area_level_2           NaN  ...                          NaN
# administrative_area_level_3           NaN  ...                          NaN
# latitude                              NaN  ...                          NaN
# longitude                             NaN  ...                          NaN
# population                            NaN  ...                          NaN
# iso_numeric                           NaN  ...                          NaN
# key_local                             NaN  ...                          NaN
# key_google_mobility                   NaN  ...                          NaN
# key_apple_mobility                    NaN  ...                          NaN
# key_jhu_csse                          NaN  ...                          NaN
# key_nuts                              NaN  ...                          NaN
#
#                                      latitude  longitude  population  \
# confirmed                                 NaN        NaN    -0.83317
# deaths                                    NaN        NaN         NaN
# recovered                                 NaN        NaN         NaN
# tests                                     NaN        NaN         NaN
# vaccines                                  NaN        NaN         NaN
# people_vaccinated                         NaN        NaN         NaN
# people_fully_vaccinated                   NaN        NaN         NaN
# hosp                                      NaN        NaN         NaN
# icu                                       NaN        NaN         NaN
# vent                                      NaN        NaN         NaN
# school_closing                            NaN        NaN         NaN
# workplace_closing                         NaN        NaN         NaN
# cancel_events                             NaN        NaN         NaN
# gatherings_restrictions                   NaN        NaN         NaN
# transport_closing                         NaN        NaN         NaN
# stay_home_restrictions                    NaN        NaN         NaN
# internal_movement_restrictions            NaN        NaN         NaN
# international_movement_restrictions       NaN        NaN         NaN
# information_campaigns                     NaN        NaN         NaN
# testing_policy                            NaN        NaN         NaN
# contact_tracing                           NaN        NaN         NaN
# facial_coverings                          NaN        NaN         NaN
# vaccination_policy                        NaN        NaN         NaN
# elderly_people_protection                 NaN        NaN         NaN
# government_response_index                 NaN        NaN         NaN
# stringency_index                          NaN        NaN         NaN
# containment_health_index                  NaN        NaN         NaN
# economic_support_index                    NaN        NaN         NaN
# administrative_area_level                 NaN        NaN         NaN
# administrative_area_level_2               NaN        NaN         NaN
# administrative_area_level_3               NaN        NaN         NaN
# latitude                                  NaN        NaN         NaN
# longitude                                 NaN        NaN         NaN
# population                                NaN        NaN     1.00000
# iso_numeric                               NaN        NaN         NaN
# key_local                                 NaN        NaN         NaN
# key_google_mobility                       NaN        NaN         NaN
# key_apple_mobility                        NaN        NaN         NaN
# key_jhu_csse                              NaN        NaN         NaN
# key_nuts                                  NaN        NaN         NaN
#
#                                      iso_numeric  key_local  \
# confirmed                                    NaN        NaN
# deaths                                       NaN        NaN
# recovered                                    NaN        NaN
# tests                                        NaN        NaN
# vaccines                                     NaN        NaN
# people_vaccinated                            NaN        NaN
# people_fully_vaccinated                      NaN        NaN
# hosp                                         NaN        NaN
# icu                                          NaN        NaN
# vent                                         NaN        NaN
# school_closing                               NaN        NaN
# workplace_closing                            NaN        NaN
# cancel_events                                NaN        NaN
# gatherings_restrictions                      NaN        NaN
# transport_closing                            NaN        NaN
# stay_home_restrictions                       NaN        NaN
# internal_movement_restrictions               NaN        NaN
# international_movement_restrictions          NaN        NaN
# information_campaigns                        NaN        NaN
# testing_policy                               NaN        NaN
# contact_tracing                              NaN        NaN
# facial_coverings                             NaN        NaN
# vaccination_policy                           NaN        NaN
# elderly_people_protection                    NaN        NaN
# government_response_index                    NaN        NaN
# stringency_index                             NaN        NaN
# containment_health_index                     NaN        NaN
# economic_support_index                       NaN        NaN
# administrative_area_level                    NaN        NaN
# administrative_area_level_2                  NaN        NaN
# administrative_area_level_3                  NaN        NaN
# latitude                                     NaN        NaN
# longitude                                    NaN        NaN
# population                                   NaN        NaN
# iso_numeric                                  NaN        NaN
# key_local                                    NaN        NaN
# key_google_mobility                          NaN        NaN
# key_apple_mobility                           NaN        NaN
# key_jhu_csse                                 NaN        NaN
# key_nuts                                     NaN        NaN
#
#                                      key_google_mobility  key_apple_mobility  \
# confirmed                                            NaN                 NaN
# deaths                                               NaN                 NaN
# recovered                                            NaN                 NaN
# tests                                                NaN                 NaN
# vaccines                                             NaN                 NaN
# people_vaccinated                                    NaN                 NaN
# people_fully_vaccinated                              NaN                 NaN
# hosp                                                 NaN                 NaN
# icu                                                  NaN                 NaN
# vent                                                 NaN                 NaN
# school_closing                                       NaN                 NaN
# workplace_closing                                    NaN                 NaN
# cancel_events                                        NaN                 NaN
# gatherings_restrictions                              NaN                 NaN
# transport_closing                                    NaN                 NaN
# stay_home_restrictions                               NaN                 NaN
# internal_movement_restrictions                       NaN                 NaN
# international_movement_restrictions                  NaN                 NaN
# information_campaigns                                NaN                 NaN
# testing_policy                                       NaN                 NaN
# contact_tracing                                      NaN                 NaN
# facial_coverings                                     NaN                 NaN
# vaccination_policy                                   NaN                 NaN
# elderly_people_protection                            NaN                 NaN
# government_response_index                            NaN                 NaN
# stringency_index                                     NaN                 NaN
# containment_health_index                             NaN                 NaN
# economic_support_index                               NaN                 NaN
# administrative_area_level                            NaN                 NaN
# administrative_area_level_2                          NaN                 NaN
# administrative_area_level_3                          NaN                 NaN
# latitude                                             NaN                 NaN
# longitude                                            NaN                 NaN
# population                                           NaN                 NaN
# iso_numeric                                          NaN                 NaN
# key_local                                            NaN                 NaN
# key_google_mobility                                  NaN                 NaN
# key_apple_mobility                                   NaN                 NaN
# key_jhu_csse                                         NaN                 NaN
# key_nuts                                             NaN                 NaN
#
#                                      key_jhu_csse  key_nuts
# confirmed                                     NaN       NaN
# deaths                                        NaN       NaN
# recovered                                     NaN       NaN
# tests                                         NaN       NaN
# vaccines                                      NaN       NaN
# people_vaccinated                             NaN       NaN
# people_fully_vaccinated                       NaN       NaN
# hosp                                          NaN       NaN
# icu                                           NaN       NaN
# vent                                          NaN       NaN
# school_closing                                NaN       NaN
# workplace_closing                             NaN       NaN
# cancel_events                                 NaN       NaN
# gatherings_restrictions                       NaN       NaN
# transport_closing                             NaN       NaN
# stay_home_restrictions                        NaN       NaN
# internal_movement_restrictions                NaN       NaN
# international_movement_restrictions           NaN       NaN
# information_campaigns                         NaN       NaN
# testing_policy                                NaN       NaN
# contact_tracing                               NaN       NaN
# facial_coverings                              NaN       NaN
# vaccination_policy                            NaN       NaN
# elderly_people_protection                     NaN       NaN
# government_response_index                     NaN       NaN
# stringency_index                              NaN       NaN
# containment_health_index                      NaN       NaN
# economic_support_index                        NaN       NaN
# administrative_area_level                     NaN       NaN
# administrative_area_level_2                   NaN       NaN
# administrative_area_level_3                   NaN       NaN
# latitude                                      NaN       NaN
# longitude                                     NaN       NaN
# population                                    NaN       NaN
# iso_numeric                                   NaN       NaN
# key_local                                     NaN       NaN
# key_google_mobility                           NaN       NaN
# key_apple_mobility                            NaN       NaN
# key_jhu_csse                                  NaN       NaN
# key_nuts                                      NaN       NaN
#
# [40 rows x 40 columns]

# %%
df['recovered']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 201    0.0
# 202    0.0
# 203    0.0
# 204    0.0
# 205    0.0
# Name: recovered, Length: 206, dtype: float64

# %%
df['tests'] + 1
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 201    624.0
# 202    624.0
# 203    624.0
# 204    624.0
# 205    624.0
# Name: tests, Length: 206, dtype: float64

# %%
df['deaths'] + df['tests']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 201    623.0
# 202    623.0
# 203    623.0
# 204    623.0
# 205    623.0
# Length: 206, dtype: float64

# %%
df[df['tests'] > 5
  
  ]
# Out:
#            id       date  confirmed  deaths  recovered  tests  vaccines  \
# 191  d7f0f2d6  23/4/2020       48.0     0.0        0.0   61.0       NaN
# 192  d7f0f2d6  24/4/2020       91.0     0.0        0.0  127.0       NaN
# 193  d7f0f2d6  25/4/2020      148.0     0.0        0.0  335.0       NaN
# 194  d7f0f2d6  26/4/2020      148.0     0.0        0.0  623.0       NaN
# 195  d7f0f2d6  27/4/2020      148.0     0.0        0.0  623.0       NaN
# 196  d7f0f2d6  28/4/2020      148.0     0.0        0.0  623.0       NaN
# 197  d7f0f2d6  29/4/2020      148.0     0.0        0.0  623.0       NaN
# 198  d7f0f2d6  30/4/2020      148.0     0.0        0.0  623.0       NaN
# 199  d7f0f2d6   1/5/2020      148.0     0.0        0.0  623.0       NaN
# 200  d7f0f2d6   2/5/2020      148.0     0.0        0.0  623.0       NaN
# 201  d7f0f2d6   3/5/2020      148.0     0.0        0.0  623.0       NaN
# 202  d7f0f2d6   4/5/2020      149.0     0.0        0.0  623.0       NaN
# 203  d7f0f2d6   5/5/2020      149.0     0.0        0.0  623.0       NaN
# 204  d7f0f2d6   6/5/2020      149.0     0.0        0.0  623.0       NaN
# 205  d7f0f2d6   7/5/2020      149.0     0.0        0.0  623.0       NaN
#
#      people_vaccinated  people_fully_vaccinated   hosp  ...  iso_alpha_3  \
# 191                NaN                      NaN   34.0  ...          NaN
# 192                NaN                      NaN   48.0  ...          NaN
# 193                NaN                      NaN   91.0  ...          NaN
# 194                NaN                      NaN  148.0  ...          NaN
# 195                NaN                      NaN  148.0  ...          NaN
# 196                NaN                      NaN  148.0  ...          NaN
# 197                NaN                      NaN  148.0  ...          NaN
# 198                NaN                      NaN  148.0  ...          NaN
# 199                NaN                      NaN  148.0  ...          NaN
# 200                NaN                      NaN  148.0  ...          NaN
# 201                NaN                      NaN  148.0  ...          NaN
# 202                NaN                      NaN  148.0  ...          NaN
# 203                NaN                      NaN  149.0  ...          NaN
# 204                NaN                      NaN  149.0  ...          NaN
# 205                NaN                      NaN  149.0  ...          NaN
#
#      iso_alpha_2  iso_numeric  iso_currency  key_local  key_google_mobility  \
# 191          NaN          NaN           NaN        NaN                  NaN
# 192          NaN          NaN           NaN        NaN                  NaN
# 193          NaN          NaN           NaN        NaN                  NaN
# 194          NaN          NaN           NaN        NaN                  NaN
# 195          NaN          NaN           NaN        NaN                  NaN
# 196          NaN          NaN           NaN        NaN                  NaN
# 197          NaN          NaN           NaN        NaN                  NaN
# 198          NaN          NaN           NaN        NaN                  NaN
# 199          NaN          NaN           NaN        NaN                  NaN
# 200          NaN          NaN           NaN        NaN                  NaN
# 201          NaN          NaN           NaN        NaN                  NaN
# 202          NaN          NaN           NaN        NaN                  NaN
# 203          NaN          NaN           NaN        NaN                  NaN
# 204          NaN          NaN           NaN        NaN                  NaN
# 205          NaN          NaN           NaN        NaN                  NaN
#
#      key_apple_mobility  key_jhu_csse  key_nuts  key_gadm
# 191                 NaN           NaN       NaN       NaN
# 192                 NaN           NaN       NaN       NaN
# 193                 NaN           NaN       NaN       NaN
# 194                 NaN           NaN       NaN       NaN
# 195                 NaN           NaN       NaN       NaN
# 196                 NaN           NaN       NaN       NaN
# 197                 NaN           NaN       NaN       NaN
# 198                 NaN           NaN       NaN       NaN
# 199                 NaN           NaN       NaN       NaN
# 200                 NaN           NaN       NaN       NaN
# 201                 NaN           NaN       NaN       NaN
# 202                 NaN           NaN       NaN       NaN
# 203                 NaN           NaN       NaN       NaN
# 204                 NaN           NaN       NaN       NaN
# 205                 NaN           NaN       NaN       NaN
#
# [15 rows x 47 columns]

# %%
df[df['class'] == 'Costa Rica']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-cf75530e1bf4> in <module>()
# ----> 1 df[df['class'] == 'Costa Rica']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'class'

# %%
df[df['class'] == 'Iris-setosa'].describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count     50.00000   50.000000    50.000000    50.00000
# mean       5.00600    3.418000     1.464000     0.24400
# std        0.35249    0.381024     0.173511     0.10721
# min        4.30000    2.300000     1.000000     0.10000
# 25%        4.80000    3.125000     1.400000     0.20000
# 50%        5.00000    3.400000     1.500000     0.20000
# 75%        5.20000    3.675000     1.575000     0.30000
# max        5.80000    4.400000     1.900000     0.60000

# %%
df[df['class'] == 'Iris-setosa'].shape
# Out:
# (50, 5)
